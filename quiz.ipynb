# %%
a = (1,2,3)
b = (3,4)

c = {*a, *b}
c
# Out:
# {1, 2, 3, 4}

# %%
dict1 = {
    "name": "ankit",
    "age": 23
}

dict2 = {
    "sport": "basketball",
    "age": 28
}

def test_func(name="", age=0):
    print(name)
    print(age)
    return 

test_func(**dict1)

final_dict = {**dict1, **dict2}

final_dict
# Out:
# ankit
# 23
# {'name': 'ankit', 'age': 28, 'sport': 'basketball'}

# %%
some_list = [1,2,3,4,5,6]
first =0
last = 0
middle = []

first, *middle, last = some_list
first, *rest = some_list

print(first,middle, last)
print(first,rest)
# Out:
# 1 [2, 3, 4, 5] 6
# 1 [2, 3, 4, 5, 6]

# %%
t = (1,2)
a,b = t
print(a,b)
# Out:
# 1 2

# %%
l = [1,2]
a,b = l

print(a,b)
# Out:
# 1 2
